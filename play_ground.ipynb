# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU available

# %%
from moviepy.editor import VideoFileClip
clip=VideoFileClip("data/archive (1)/RAVDESS dataset/Video_Speech_Actor_01/Actor_01/01-01-05-01-01-01-01.mp4").resize(width=256,height=256)
clip.fps
#clip.ipython_display()
# Out:
# 29.97002997002997

# %%
sr=8000
ad=clip.subclip(t_start=1,t_end=1.2).audio.to_soundarray(fps=sr)
ad.shape
# Out:
# (1600, 2)

# %%
ad.shape[0]/clip.duration
# Out:
# 410.2564102564103

# %%
import librosa
mel=librosa.feature.melspectrogram(y=ad, sr=sr )
mel.shape

# %%
mel.min()
# Out:
# 0.0

# %%
mel.dtype
# Out:
# dtype('float64')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 4))
log_mel_spectrogram = librosa.power_to_db(mel.squeeze(axis=2)).astype(np.float32)
librosa.display.specshow(log_mel_spectrogram, y_axis='mel', x_axis='time')
plt.colorbar(format="%+2.f dB")
plt.title("Mel Spectrogram")
plt.show()

# %%
# %matplotlib inline
from src.data import visualize_one_batch, get_data_loaders

# use get_data_loaders to get the data_loaders dictionary. Use a batch_size
# of 5, a validation size of 0.01 and num_workers=-1 (all CPUs)
data_loaders = get_data_loaders(batch_size=6, num_workers=2, is_mel=False)
print(len(data_loaders['valid']))
# Out:
# Dataset mean: tensor([0.4850, 0.4560, 0.4060]), std: tensor([0.2290, 0.2240, 0.2250])
# 875

# %%
images, labels=next(iter(data_loaders['valid']))
len(labels.unique())
# Out:
# 5

# %%
images[0].shape
# Out:
# torch.Size([3, 230, 230])

# %%
valid_im_size=220

# %%
im_deff= (images[0].shape[-1]-valid_im_size)//2
last_cut=images[0].shape[-1]-im_deff
x = images[0][:,im_deff:last_cut,im_deff:last_cut]
x.shape
# Out:
# torch.Size([3, 220, 220])

# %%
im_deff,last_cut
# Out:
# (5, 225)

# %%
from src.train import to_device
images, labels=to_device(images, labels)
images[0].shape
# Out:
# torch.Size([6, 3, 200, 200])

# %%
len(labels)
# Out:
# 128

# %%
import torch
from src.models.image import MyModel2
torch_model=MyModel2(num_classes=8)
torch_input = torch.randn(1, 3, 256, 256)
onnx_program = torch.onnx.dynamo_export(torch_model, torch_input)
onnx_program
# Out:
# /home/naif/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/exporter.py:136: UserWarning: torch.onnx.dynamo_export only implements opset version 18 for now. If you need to use a different opset version, please register them with register_custom_op.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/exporter.py:1428, in dynamo_export(model, export_options, *model_args, **model_kwargs)
#    1422 try:
#    1423     return Exporter(
#    1424         options=resolved_export_options,
#    1425         model=model,
#    1426         model_args=model_args,
#    1427         model_kwargs=model_kwargs,
# -> 1428     ).export()
#    1429 except Exception as e:
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/exporter.py:1171, in Exporter.export(self)
#    1168 with self.options.diagnostic_context, decomposition_skip.enable_decomposition_skips(
#    1169     self.options
#    1170 ):
# -> 1171     graph_module = self.options.fx_tracer.generate_fx(
#    1172         self.options, self.model, self.model_args, self.model_kwargs
#    1173     )
#    1174     # TODO: Defer `import onnxscript` out of `import torch` path
#    1175     # https://github.com/pytorch/pytorch/issues/103764
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/fx/dynamo_graph_extractor.py:232, in DynamoExport.generate_fx(self, options, model, model_args, model_kwargs)
#     228 updated_model_args = self.input_adapter.apply(
#     229     *model_args, model=model, **model_kwargs
#     230 )
# --> 232 return self.pre_export_passes(options, model, graph_module, updated_model_args)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/fx/dynamo_graph_extractor.py:242, in DynamoExport.pre_export_passes(self, options, original_model, fx_module, fx_module_args)
#     234 @_beartype.beartype
#     235 def pre_export_passes(
#     236     self,
#    (...)
#     240     fx_module_args: Sequence[Any],
#     241 ):
# --> 242     return exporter.common_pre_export_passes(
#     243         options, original_model, fx_module, fx_module_args
#     244     )
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/exporter.py:1467, in common_pre_export_passes(options, original_model, fx_module, fx_module_args)
#    1465 # ONNX does not support views and mutations.
#    1466 # Functionalize to get a semantically equivalent graph without mutations.
# -> 1467 module = passes.Functionalize(
#    1468     diagnostic_context,
#    1469     module,
#    1470     enable_dynamic_axes=options.dynamic_shapes,
#    1471     allow_fake_constant=options.fake_context is not None,
#    1472 ).run(*fx_module_args)
#    1474 # Input mutations are detected and distilled after `Functionalize` pass.
#    1475 # Remove them since ONNX inference does not need them.
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/diagnostics/infra/decorator.py:151, in diagnose_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     150 finally:
# --> 151     ctx.log_and_raise_if_error(diag)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/diagnostics/infra/context.py:366, in DiagnosticContext.log_and_raise_if_error(self, diagnostic)
#     365 if diagnostic.source_exception is not None:
# --> 366     raise diagnostic.source_exception
#     367 raise RuntimeErrorWithDiagnostic(diagnostic)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/diagnostics/infra/decorator.py:135, in diagnose_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     134 try:
# --> 135     return_values = fn(*args, **kwargs)
#     136     with diag.log_section(logging.INFO, "Return values"):
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/fx/_pass.py:275, in Transform.run(self, *args, **kwargs)
#     273     old_tabular = ""
# --> 275 module = self._run(*args, **kwargs)
#     277 # Gather graph information after transform.
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/fx/passes/functionalization.py:123, in Functionalize._run(self, *args)
#     122 with proxy_tensor.maybe_disable_fake_tensor_mode(), fake_mode:
# --> 123     graph_module = proxy_tensor.make_fx(
#     124         functionalized_callable,
#     125         decomposition_table={},
#     126         tracing_mode=tracing_mode,
#     127         _allow_non_fake_inputs=True,
#     128         _allow_fake_constant=self.allow_fake_constant,
#     129     )(*maybe_fake_args)
#     131 # Rename placeholder targets to match the original module's signature since
#     132 # We don't want to map forward(x, y, z) to forward(arg0, arg1, arg2).
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:1081, in make_fx.<locals>.wrapped(*args)
#    1079 with decompose(decomposition_table), fake_tensor_mode, python_dispatcher_mode, pre_dispatch_mode, proxy_function_mode, \
#    1080      sym_mode, proxy_mode, disable_autocast_cache():
# -> 1081     t = dispatch_trace(wrap_key(func, args, fx_tracer, pre_dispatch), tracer=fx_tracer, concrete_args=tuple(phs))
#    1083 # TODO: kind of a bad way to do it, should maybe figure out a better way
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/_compile.py:24, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      22 import torch._dynamo
# ---> 24 return torch._dynamo.disable(fn, recursive)(*args, **kwargs)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:451, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     450 try:
# --> 451     return fn(*args, **kwargs)
#     452 finally:
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/_dynamo/external_utils.py:36, in wrap_inline.<locals>.inner(*args, **kwargs)
#      34 @functools.wraps(fn)
#      35 def inner(*args, **kwargs):
# ---> 36     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:541, in dispatch_trace(root, tracer, concrete_args)
#     535 @torch._disable_dynamo
#     536 def dispatch_trace(
#     537         root: Union[torch.nn.Module, Callable],
#     538         tracer: Tracer,
#     539         concrete_args: Optional[Tuple[Any, ...]] = None,
#     540 ) -> GraphModule:
# --> 541     graph = tracer.trace(root, concrete_args)
#     542     from torch._inductor.fx_passes.dedupe_symint_uses import dedupe_symints
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/_dynamo/eval_frame.py:451, in _TorchDynamoContext.__call__.<locals>._fn(*args, **kwargs)
#     450 try:
# --> 451     return fn(*args, **kwargs)
#     452 finally:
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/_dynamo/external_utils.py:36, in wrap_inline.<locals>.inner(*args, **kwargs)
#      34 @functools.wraps(fn)
#      35 def inner(*args, **kwargs):
# ---> 36     return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/_symbolic_trace.py:793, in Tracer.trace(self, root, concrete_args)
#     787         _autowrap_check(
#     788             patcher, module.__dict__, self._autowrap_function_ids
#     789         )
#     790     self.create_node(
#     791         "output",
#     792         "output",
# --> 793         (self.create_arg(fn(*args)),),
#     794         {},
#     795         type_expr=fn.__annotations__.get("return", None),
#     796     )
#     798 self.submodule_paths = None
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/experimental/proxy_tensor.py:559, in wrap_key.<locals>.wrapped(*proxies)
#     557     track_tensor_tree(flat_tensors, flat_proxies, constant=None, tracer=tracer)
# --> 559 out = f(*tensors)
#     560 out = pytree.tree_map_only(
#     561     torch.Tensor,
#     562     lambda t: get_proxy_slot(t, tracer, t, lambda x: x.proxy),
#     563     out
#     564 )
#
# File <string>:1, in <lambda>(arg0)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/fx/passes/functionalization.py:86, in Functionalize._functionalize.<locals>.wrapped(*inputs)
#      85 try:
# ---> 86     out = function(*inputs_functional)
#      87 finally:
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/fx/passes/_utils.py:30, in wrap_graph_module_for_node_meta_preservation.<locals>.wrapped(*args)
#      29 with fx_traceback.preserve_node_meta():
# ---> 30     return torch.fx.Interpreter(graph_module).run(*args)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/interpreter.py:145, in Interpreter.run(self, initial_env, enable_io_processing, *args)
#     144 try:
# --> 145     self.env[node] = self.run_node(node)
#     146 except Exception as e:
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/interpreter.py:202, in Interpreter.run_node(self, n)
#     201 assert isinstance(kwargs, dict)
# --> 202 return getattr(self, n.op)(n.target, args, kwargs)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/fx/interpreter.py:274, in Interpreter.call_function(self, target, args, kwargs)
#     273 # Execute the function and return the result
# --> 274 return target(*args, **kwargs)
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/_ops.py:594, in OpOverload.__call__(self_, *args, **kwargs)
#     591 def __call__(self_, *args, **kwargs):  # noqa: B902
#     592     # use `self_` to avoid naming collide with aten ops arguments that
#     593     # are named "self". This way, all the aten ops can be called by kwargs.
# --> 594     return self_._op(*args, **kwargs)
#
# RuntimeError: false INTERNAL ASSERT FAILED at "/opt/conda/conda-bld/pytorch_1712608853085/work/build/aten/src/ATen/RegisterFunctionalization_2.cpp":8048, please report a bug to PyTorch. mutating a non-functional tensor with a functional tensor is not allowed. Please ensure that all of your inputs are wrapped inside of a functionalize() call.
#
# While executing %_native_batch_norm_legit : [num_users=3] = call_function[target=torch.ops.aten._native_batch_norm_legit.default](args = (%convolution, %_param_constant2, %_param_constant3, %_tensor_constant1, %_tensor_constant2, True, 0.1, 1e-05), kwargs = {})
# Original traceback:
#   File "/home/naif/projects/videoEmotionRecognition/src/models/image.py", line 120, in forward
#     x=self.Dconvs(x)
#
#
# The above exception was the direct cause of the following exception:
#
# OnnxExporterError                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 torch_model=MyModel2(num_classes=8)
#       4 torch_input = torch.randn(1, 3, 256, 256)
# ----> 5 onnx_program = torch.onnx.dynamo_export(torch_model, torch_input)
#       6 onnx_program
#
# File ~/miniconda3/envs/MLenv/lib/python3.11/site-packages/torch/onnx/_internal/exporter.py:1439, in dynamo_export(model, export_options, *model_args, **model_kwargs)
#    1431 resolved_export_options.diagnostic_context.dump(sarif_report_path)
#    1432 message = (
#    1433     f"Failed to export the model to ONNX. Generating SARIF report at '{sarif_report_path}'. "
#    1434     "SARIF is a standard format for the output of static analysis tools. "
#    (...)
#    1437     f"Please report a bug on PyTorch Github: {_PYTORCH_GITHUB_ISSUES_URL}"
#    1438 )
# -> 1439 raise OnnxExporterError(
#    1440     ONNXProgram._from_failure(e, resolved_export_options.diagnostic_context),
#    1441     message,
#    1442 ) from e
#
# OnnxExporterError: Failed to export the model to ONNX. Generating SARIF report at 'report_dynamo_export.sarif'. SARIF is a standard format for the output of static analysis tools. SARIF logs can be loaded in VS Code SARIF viewer extension, or SARIF web viewer (https://microsoft.github.io/sarif-web-component/). Please report a bug on PyTorch Github: https://github.com/pytorch/pytorch/issues

# %% [markdown]
# --------------------------

# %%
from src.predictor import Predictor
from src.helpers import compute_mean_and_std
from src.models.image import get_model_transfer_learning
from src.data import get_data_loaders
from src.data import valid_im_size
import torch

data_loaders = get_data_loaders(batch_size=1)

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes


# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model = get_model_transfer_learning('shufflenet_v2_x1_0',n_classes=8).cpu()

# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)

model.load_state_dict(torch.load('checkpoints/best_shufflenet_v2_x1_0.pt')['model_state_dict'])

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model, class_names,valid_im_size, mean, std).cpu()


# dummy_input = torch.zeros(1,3,256,256)
# # inputs = ['images']
# # outputs = ['scores']
# # dynamic_axes= {'input':{0:'batch_size' , 2:'width', 3:'height'}, 'output':{0:'batch_size' , 2:'width', 3:'height'}}
# torch.onnx.export(predictor, dummy_input, 'model.onnx', verbose=True)


# Export using torch.jit.script
scripted_predictor =torch.jit.script(predictor) 

scripted_predictor.save("checkpoints/original_exported.pt")
# Out:
# Dataset mean: tensor([0.4850, 0.4560, 0.4060]), std: tensor([0.2290, 0.2240, 0.2250])

# %%
predictor.class_names[0]
# Out:
# 'Angry'

# %%
predictor.class_names.codes
# Out:
# 10076    2
# 4059     7
# 8373     5
# 14675    3
# 21429    4
#         ..
# 6495     1
# 3887     0
# 2677     1
# 8434     1
# 5716     2
# Length: 20993, dtype: int8
